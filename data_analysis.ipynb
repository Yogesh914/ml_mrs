# %%
selected_features = [
    "habituation",
    "HRV_GI",
    "HRV_MFDFA_alpha1_Asymmetry",
    "HR_5min.0_max_HRV_pNN20",
    "feature_max",
    "stress_load_geometric",
    "p114_t1",
    "HRV_MeanNN_exp_decay",
    "HRV_kurtosis",
    "sCortisol",
    "HRV_SI",
    "HRV_Cd",
    "HRV_MFDFA_alpha1_Delta",
    "autonomic_balance",
    "uNE",
    "base",
    "feature_mad",
]
len(selected_features)
# Out:
# 17

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd 

df = pd.read_csv('synthetic_physiological_data/physiological_synthetic_data.csv')
df
# Out:
#      HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_RMSSD  HRV_SDSD  \
# 0         775.0      73.0        20.0        70.0       50.0      50.0
# 1         980.0      44.0        17.0        41.0       46.0      46.0
# 2         840.0      58.0        39.0        47.0       47.0      47.0
# 3        1025.0     105.0        48.0        82.0       85.0      85.0
# 4         835.0      40.0        13.0        38.0       40.0      40.0
# ..          ...       ...         ...         ...        ...       ...
# 497       845.0      52.0         8.0        51.0       44.0      44.0
# 498       980.0     110.0        53.0       100.0       82.0      83.0
# 499       760.0      37.0        20.0        32.0       22.0      22.0
# 500       870.0      75.0        33.0        68.0       68.0      67.0
# 501       840.0      63.0         9.0        59.0       75.0      76.0
#
#      HRV_CVNN  HRV_CVSD  HRV_MedianNN  HRV_MadNN  ...   p85    p90    p95  \
# 0        0.09      0.06         780.0       55.0  ...  15.5   10.0   13.5
# 1        0.04      0.04         985.0       46.0  ...  14.5   11.0   22.0
# 2        0.07      0.06         835.0       50.0  ...  15.5   81.0  165.0
# 3        0.11      0.09        1020.0       50.0  ...  47.0   52.0   61.0
# 4        0.05      0.05         830.0       42.0  ...  87.0  185.0  710.0
# ..        ...       ...           ...        ...  ...   ...    ...    ...
# 497      0.06      0.05         850.0       48.0  ...  14.0   72.0  236.0
# 498      0.11      0.08         980.0      110.0  ...  14.0   12.0   63.0
# 499      0.05      0.03         765.0       34.0  ...  11.0   12.0   14.0
# 500      0.09      0.08         870.0       75.0  ...   7.0   12.0   22.0
# 501      0.07      0.09         850.0       27.0  ...  22.0   22.0   52.0
#
#       p100    p105  p114_t1  isi30  isi60  isi120  CAPSF1I2s.0
# 0     21.0    66.0    117.0   50.0   38.0    60.0          0.0
# 1     11.5    19.0    485.0   36.0   50.0    36.0          0.0
# 2    201.0   247.0    513.0   75.0   88.0    87.0          0.0
# 3    127.0   206.0    492.0   49.0   43.0    69.0          0.0
# 4    890.0  1065.0    663.0  -28.0  -10.0    11.0          0.0
# ..     ...     ...      ...    ...    ...     ...          ...
# 497  250.0   460.0    810.0  -45.0   27.0    10.0          1.0
# 498   42.0   135.0    470.0   73.0   39.0    67.0          1.0
# 499   20.0    35.0     28.0   36.0   -9.0    51.0          1.0
# 500  167.0   115.0    245.0   34.0   24.0    34.0          1.0
# 501  138.0   129.0    237.0   63.0   66.0    82.0          1.0
#
# [502 rows x 141 columns]

# %%
df['CAPSF1I2s.0'].value_counts()
# Out:
# CAPSF1I2s.0
# 1.0    267
# 0.0    235
# Name: count, dtype: int64

# %%
# remove nan rows and rows with CAPSF1I2s.0 != 0 or 1

import pandas as pd 

df = pd.read_csv('synthetic_physiological_data/physiological_synthetic_data.csv')
df = df[df['CAPSF1I2s.0'].isin([0, 1])]
df = df.dropna()
df
# Out:
#      HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_RMSSD  HRV_SDSD  \
# 0         775.0      73.0        20.0        70.0       50.0      50.0
# 1         980.0      44.0        17.0        41.0       46.0      46.0
# 2         840.0      58.0        39.0        47.0       47.0      47.0
# 3        1025.0     105.0        48.0        82.0       85.0      85.0
# 4         835.0      40.0        13.0        38.0       40.0      40.0
# ..          ...       ...         ...         ...        ...       ...
# 507       845.0      52.0         8.0        51.0       44.0      44.0
# 508       980.0     110.0        53.0       100.0       82.0      83.0
# 509       760.0      37.0        20.0        32.0       22.0      22.0
# 510       870.0      75.0        33.0        68.0       68.0      67.0
# 511       840.0      63.0         9.0        59.0       75.0      76.0
#
#      HRV_CVNN  HRV_CVSD  HRV_MedianNN  HRV_MadNN  ...   p85    p90    p95  \
# 0        0.09      0.06         780.0       55.0  ...  15.5   10.0   13.5
# 1        0.04      0.04         985.0       46.0  ...  14.5   11.0   22.0
# 2        0.07      0.06         835.0       50.0  ...  15.5   81.0  165.0
# 3        0.11      0.09        1020.0       50.0  ...  47.0   52.0   61.0
# 4        0.05      0.05         830.0       42.0  ...  87.0  185.0  710.0
# ..        ...       ...           ...        ...  ...   ...    ...    ...
# 507      0.06      0.05         850.0       48.0  ...  14.0   72.0  236.0
# 508      0.11      0.08         980.0      110.0  ...  14.0   12.0   63.0
# 509      0.05      0.03         765.0       34.0  ...  11.0   12.0   14.0
# 510      0.09      0.08         870.0       75.0  ...   7.0   12.0   22.0
# 511      0.07      0.09         850.0       27.0  ...  22.0   22.0   52.0
#
#       p100    p105  p114_t1  isi30  isi60  isi120  CAPSF1I2s.0
# 0     21.0    66.0    117.0   50.0   38.0    60.0          0.0
# 1     11.5    19.0    485.0   36.0   50.0    36.0          0.0
# 2    201.0   247.0    513.0   75.0   88.0    87.0          0.0
# 3    127.0   206.0    492.0   49.0   43.0    69.0          0.0
# 4    890.0  1065.0    663.0  -28.0  -10.0    11.0          0.0
# ..     ...     ...      ...    ...    ...     ...          ...
# 507  250.0   460.0    810.0  -45.0   27.0    10.0          1.0
# 508   42.0   135.0    470.0   73.0   39.0    67.0          1.0
# 509   20.0    35.0     28.0   36.0   -9.0    51.0          1.0
# 510  167.0   115.0    245.0   34.0   24.0    34.0          1.0
# 511  138.0   129.0    237.0   63.0   66.0    82.0          1.0
#
# [502 rows x 141 columns]

# %%
df.to_csv('synthetic_physiological_data/physiological_synthetic_data.csv', index=False)

# %%
import pickle

with open('pre_deployment_data.pkl', 'rb') as f:
    data_dict = pickle.load(f)

merged_df = data_dict['merged_df']
HRV_features = data_dict['HRV_features']
EMG_features = data_dict['EMG_features']
CUT_features = data_dict['CUT_feature']
SPSS_features = data_dict['SPSS_feature']
categorical_features = data_dict['categorical_features']
PTSD_features = data_dict['PTSD_features']

data_dict['numeric_features']

features_cut = ['age','pCRP','pNPY','uE','uNE','sCortisol','sAlpha_Amylase','sCotinine',\
             'systolic_use','diastolic_use','BMI','waist','MAP']

# Find features that are in both data_dict['numeric_features'] and features_cut
common_features = [f for f in features_cut if f in data_dict['numeric_features']]
print("Features in both lists:", common_features)
# Out:
# Features in both lists: ['age', 'pCRP', 'pNPY', 'uE', 'uNE', 'sCortisol', 'sAlpha_Amylase', 'sCotinine', 'systolic_use', 'diastolic_use', 'BMI', 'waist', 'MAP']

# %%
len(common_features), len(features_cut)
# Out:
# (13, 13)

# %%
list1 = ['string1', 'string2'] 
list2 = ['string1']

for f in list1:
    for i in list2:
        if i == f:
            list1.remove(f)

# %%
list1
# Out:
# ['string2']

# %%
import pickle

with open('combined.pkl', 'rb') as f:
    data_dict = pickle.load(f)

data_dict
# Out:
# /var/folders/39/1dgv6b0x4lz6pbcy5_ylf5g40000gn/T/ipykernel_31639/3031440455.py:4: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data_dict = pickle.load(f)
#       subjectID    HR_5min  HRnooutliers          VLF            LF  \
# 0      pre_1000  61.019812     61.019812  2223.766360   6566.874627
# 1      pre_1001  74.745672     74.745672  2579.528181   4425.009953
# 2      pre_1002  65.880525     65.880525  3040.564853   4787.981107
# 3      pre_1003  75.759202     75.759202  3147.879519  15934.098692
# 4      pre_1004  66.493104     66.493104  4422.193500   4186.470036
# ...         ...        ...           ...          ...           ...
# 5225  post_5041        NaN           NaN          NaN           NaN
# 5226  post_5044  77.017760     77.017760   475.071921   1138.407864
# 5227  post_5045  78.997664     78.997664   636.047327   2114.217919
# 5228  post_5046  63.483106     63.483106  2984.577354   3753.850141
# 5229  post_5047  52.725968     52.725968          NaN           NaN
#
#                HF     lnVLF      lnHF    lnLFHF  lnVLFnooutliers  ...  \
# 0     3783.721057  7.706958  8.238463  0.551330         7.706958  ...
# 1     6010.148870  7.855362  8.701205 -0.306177         7.855362  ...
# 2     2010.529916  8.019799  7.606154  0.867710         8.019799  ...
# 3     5556.313489  8.054484  8.622690  1.053527         8.054484  ...
# 4     1720.385080  8.394391  7.450303  0.889310         8.394391  ...
# ...           ...       ...       ...       ...              ...  ...
# 5225          NaN       NaN       NaN       NaN              NaN  ...
# 5226  1967.180402  6.163466  7.584357 -0.546971         6.163466  ...
# 5227  1031.899202  6.455273  6.939156  0.717284         6.455273  ...
# 5228  2567.321229  8.001213  7.850618  0.379919         8.001213  ...
# 5229          NaN       NaN       NaN       NaN              NaN  ...
#
#       Sympathetic_vagalbalance  CAPSF1I2s  CAPSF1I23s_lenient  \
# 0                     1.735560          0                   0
# 1                     0.736256          0                   0
# 2                     2.381452          0                   0
# 3                     2.867747          0                   0
# 4                     2.433449          0                   0
# ...                        ...        ...                 ...
# 5225                       NaN          0                   0
# 5226                  0.578700          0                   1
# 5227                  2.048861          0                   0
# 5228                  1.462166          0                   0
# 5229                       NaN          0                   0
#
#       CAPSF1I2s_stringent      LFHF       pCRP        pNPY         uE  \
# 0                       0  1.735560   0.230700   93.065797   4.048067
# 1                       0  0.736256   1.579300   49.381889  12.135511
# 2                       0  2.381452   0.941900   40.963085   2.605511
# 3                       0  2.867747   0.280500  300.000000  21.307110
# 4                       0  2.433449   1.268700   75.086531   2.797750
# ...                   ...       ...        ...         ...        ...
# 5225                    0       NaN   0.716546  102.036117   7.665486
# 5226                    1  0.578700   3.196965   91.979048  11.063013
# 5227                    0  2.048861  20.476028   75.746901   1.228593
# 5228                    0  1.462166   2.221943   99.033773  11.906006
# 5229                    0       NaN   0.133438   86.821969   8.375403
#
#             uNE  d_label
# 0     24.200633        1
# 1     66.755474        1
# 2     32.773094        0
# 3     63.767052        1
# 4     14.154675        1
# ...         ...      ...
# 5225  79.198051        1
# 5226  50.288230        1
# 5227  95.689501        1
# 5228  70.376080        0
# 5229  31.978890        1
#
# [4193 rows x 32 columns]

# %%
import pickle
import pandas as pd
import numpy as np

with open('./data/pre_deployment_data.pkl', 'rb') as f:
    data_dict_pre = pickle.load(f)


with open('./data/post_deployment_data.pkl', 'rb') as f:
    data_dict_post = pickle.load(f)

# %%
df_pre = data_dict_pre['merged_df']
df_post = data_dict_post['merged_df']

df_pre = df_pre[df_post.columns]

# Filter out any rows where CAPSF1I2s.0 is not 0 or 1
df_pre = df_pre[df_pre['CAPSF1I2s.0'].isin([0, 1])]
df_post = df_post[df_post['CAPSF1I2s.0'].isin([0, 1])]

# Check for duplicate subject IDs
print("Pre-deployment duplicate subjects:", df_pre['subjectID'].duplicated().sum())
print("Post-deployment duplicate subjects:", df_post['subjectID'].duplicated().sum())

# Remove duplicates if any (keeping first occurrence)
df_pre = df_pre.drop_duplicates(subset='subjectID', keep='first')
df_post = df_post.drop_duplicates(subset='subjectID', keep='first')

# Find subjects where CAPSF1I2s.0 value changed between pre and post
pre_ptsd = df_pre.set_index('subjectID')['CAPSF1I2s.0']
post_ptsd = df_post.set_index('subjectID')['CAPSF1I2s.0']

# Find common subjects between pre and post
common_subjects = set(pre_ptsd.index) & set(post_ptsd.index)
print(f"Common subjects: {len(common_subjects)}")

# Vectorized approach to find subjects where PTSD status changed
# Convert set to list for pandas indexing
common_subjects_list = list(common_subjects)

# Align the series to only include common subjects
pre_aligned = pre_ptsd.loc[common_subjects_list]
post_aligned = post_ptsd.loc[common_subjects_list]

# Find where values are different
changed_mask = pre_aligned != post_aligned
changed_subjects = changed_mask[changed_mask].index.tolist()

print(f"Subjects with changed PTSD status: {len(changed_subjects)}")

# Count subjects who changed from 0 to 1 (developed PTSD)
from_0_to_1 = ((pre_aligned == 0) & (post_aligned == 1)).sum()
print(f"Subjects who changed from 0 to 1 (developed PTSD): {from_0_to_1}")

# Count subjects who changed from 1 to 0 (recovered from PTSD)
from_1_to_0 = ((pre_aligned == 1) & (post_aligned == 0)).sum()
print(f"Subjects who changed from 1 to 0 (recovered from PTSD): {from_1_to_0}")

# Create dataframe with post-deployment data for subjects who changed PTSD status
df_changed = df_post[df_post['subjectID'].isin(changed_subjects)].copy()
df_changed.reset_index(inplace=True, drop=True)
# Out:
# Pre-deployment duplicate subjects: 0
# Post-deployment duplicate subjects: 16
# Common subjects: 1399
# Subjects with changed PTSD status: 101
# Subjects who changed from 0 to 1 (developed PTSD): 51
# Subjects who changed from 1 to 0 (recovered from PTSD): 50

# %%
df_pre[df_pre['subjectID'] == '1106']['CAPSF1I2s.0'], df_post[df_post['subjectID'] == '1106']['CAPSF1I2s.0']
# Out:
# (104    1
#  Name: CAPSF1I2s.0, dtype: Int64,
#  4    0
#  Name: CAPSF1I2s.0, dtype: Int64)

# %%
df_changed
# Out:
#     subjectID   HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1   HRV_RMSSD  \
# 0        1103   844.694362   49.396281   10.552516   46.869885   38.461445
# 1        1106  1022.132143  239.465340   43.227441  238.625737  231.194591
# 2        1147   748.060914  217.275804   44.589480  213.822539  264.102874
# 3        1170   789.476454   65.809364   25.419929   60.823859   51.718469
# 4        1225   831.713450   30.108207   12.432670   27.024345   17.756994
# ..        ...          ...         ...         ...         ...         ...
# 96       4770   752.045685   37.267589   23.253304   31.182524   29.935427
# 97       4800   888.815625   32.676726   15.479807   29.705731   32.065225
# 98       4824   731.089514   40.669899   16.581435   36.395343   21.355837
# 99       4829   946.306667   74.373364   25.286835   71.201458   77.359799
# 100      4837   854.056716   49.508057   18.521999   45.599722   41.676937
#
#        HRV_SDSD  HRV_CVNN  HRV_CVSD  HRV_MedianNN  ...  p114_t1   isi30  \
# 0     38.518632  0.058478  0.045533         847.0  ...     1219   17.24
# 1    231.588087  0.234280  0.226189        1009.0  ...      212  -66.83
# 2    264.437330  0.290452  0.353050         810.5  ...      200   17.78
# 3     51.789897  0.083358  0.065510         796.0  ...      882  -24.43
# 4     17.782244  0.036200  0.021350         835.5  ...       86   21.05
# ..          ...       ...       ...           ...  ...      ...     ...
# 96    29.973577  0.049555  0.039805         748.0  ...      NaN   64.56
# 97    32.115568  0.036764  0.036076         889.5  ...       46  -44.57
# 98    21.383247  0.055629  0.029211         734.0  ...      534   42.77
# 99    77.488965  0.078593  0.081749         946.0  ...     1026   -8.14
# 100   41.739455  0.057968  0.048799         855.0  ...       57  -11.11
#
#      isi60  isi120     LFHF.0        age      pCRP        pNPY         uE  \
# 0    17.93   62.41   3.021826  22.255327  4.840054   69.385905  12.759023
# 1    -6.53   49.75   1.613153  21.450423  0.185816   36.769127        NaN
# 2    55.56   52.22        NaN  21.750871  0.489565   69.982068  16.387704
# 3    33.89    71.1  11.405681  21.869301  0.139873   32.842554  10.515246
# 4    21.05      50   2.200337  22.033567  0.416367  143.105061   5.515537
# ..     ...     ...        ...        ...       ...         ...        ...
# 96   59.49   59.49   1.102096  23.143053  2.387282  132.967404   1.207906
# 97   19.57   36.96   1.347975  22.750833  0.153489  109.419393  16.694944
# 98   82.23   79.75   7.698438  23.742642  1.376560  105.383050   7.238409
# 99   74.03   86.63   1.004884  24.381229  0.273355   94.307459  24.170601
# 100  14.81  -25.93   1.259509  21.153951  0.779189   70.661534  23.446396
#
#             uNE
# 0     51.895397
# 1     32.679094
# 2     41.837296
# 3     25.122590
# 4     26.379963
# ..          ...
# 96   128.745242
# 97    48.834426
# 98    42.863030
# 99    39.876161
# 100   47.379662
#
# [101 rows x 136 columns]

# %%
with open('post_deployment_data.pkl', 'rb') as f:
    data_dict_post = pickle.load(f)

data_dict_post['merged_df'] = df_changed

# %%
with open('post_deployment_data_changed_ptsd.pkl', 'wb') as f:
    pickle.dump(data_dict_post, f)

print("Saved post-deployment data for subjects with changed PTSD status")
# Out:
# Saved post-deployment data for subjects with changed PTSD status

# %%
import pickle
import pandas as pd
import numpy as np

with open('pre_deployment_data.pkl', 'rb') as f:
    data_dict_pre = pickle.load(f)


with open('post_deployment_data.pkl', 'rb') as f:
    data_dict_post = pickle.load(f)

# %%
df_pre = data_dict_pre['merged_df']
df_post = data_dict_post['merged_df']

df_pre = df_pre[df_post.columns]

# Filter out any rows where CAPSF1I2s.0 is not 0 or 1
df_pre = df_pre[df_pre['CAPSF1I2s.0'].isin([0, 1])]
df_post = df_post[df_post['CAPSF1I2s.0'].isin([0, 1])]

#drop all na
df_pre = df_pre.dropna()
df_post = df_post.dropna()

# Check for duplicate subject IDs
print("Pre-deployment duplicate subjects:", df_pre['subjectID'].duplicated().sum())
print("Post-deployment duplicate subjects:", df_post['subjectID'].duplicated().sum())

# Remove duplicates if any (keeping first occurrence)
df_pre = df_pre.drop_duplicates(subset='subjectID', keep='first')
df_post = df_post.drop_duplicates(subset='subjectID', keep='first')
# Out:
# Pre-deployment duplicate subjects: 0
# Post-deployment duplicate subjects: 0

# %%
# Check data types for non-numeric columns
print("2. DATA TYPE ANALYSIS")
print("-" * 40)

# Get non-numeric columns for df_pre
non_numeric_pre = df_pre.select_dtypes(exclude=[np.number]).columns.tolist()
print(f"Non-numeric columns in df_pre: {non_numeric_pre}")
if non_numeric_pre:
    print("Data types:")
    for col in non_numeric_pre:
        print(f"  {col}: {df_pre[col].dtype}")

# Get non-numeric columns for df_post
non_numeric_post = df_post.select_dtypes(exclude=[np.number]).columns.tolist()
print(f"\nNon-numeric columns in df_post: {non_numeric_post}")
if non_numeric_post:
    print("Data types:")
    for col in non_numeric_post:
        print(f"  {col}: {df_post[col].dtype}")

# Check if there are differences in non-numeric columns between datasets
common_non_numeric = set(non_numeric_pre).intersection(set(non_numeric_post))
pre_only_non_numeric = set(non_numeric_pre) - set(non_numeric_post)
post_only_non_numeric = set(non_numeric_post) - set(non_numeric_pre)

print(f"\nCommon non-numeric columns: {list(common_non_numeric)}")
print(f"Non-numeric columns only in pre: {list(pre_only_non_numeric)}")
print(f"Non-numeric columns only in post: {list(post_only_non_numeric)}")

# Show sample values for non-numeric columns if they exist
if non_numeric_pre:
    print(f"\nSample values from non-numeric columns in df_pre:")
    for col in non_numeric_pre[:3]:  # Show first 3 non-numeric columns
        print(f"  {col}: {df_pre[col].head(3).tolist()}")

if non_numeric_post:
    print(f"\nSample values from non-numeric columns in df_post:")
    for col in non_numeric_post[:3]:  # Show first 3 non-numeric columns
        print(f"  {col}: {df_post[col].head(3).tolist()}")

# Convert non-numeric columns to numeric types
print("\n3. CONVERTING NON-NUMERIC COLUMNS")
print("-" * 40)

# Convert non-numeric columns in df_pre
for col in non_numeric_pre:
    try:
        # Check if values contain decimal points to decide between int and float
        sample_val = str(df_pre[col].dropna().iloc[0]) if not df_pre[col].dropna().empty else "0"
        if '.' in sample_val:
            df_pre[col] = pd.to_numeric(df_pre[col], errors='coerce').astype(float)
            print(f"Converted df_pre['{col}'] to float")
        else:
            df_pre[col] = pd.to_numeric(df_pre[col], errors='coerce').astype(int)
            print(f"Converted df_pre['{col}'] to int")
    except Exception as e:
        print(f"Error converting df_pre['{col}']: {e}")

# Convert non-numeric columns in df_post
for col in non_numeric_post:
    try:
        # Check if values contain decimal points to decide between int and float
        sample_val = str(df_post[col].dropna().iloc[0]) if not df_post[col].dropna().empty else "0"
        if '.' in sample_val:
            df_post[col] = pd.to_numeric(df_post[col], errors='coerce').astype(float)
            print(f"Converted df_post['{col}'] to float")
        else:
            df_post[col] = pd.to_numeric(df_post[col], errors='coerce').astype(int)
            print(f"Converted df_post['{col}'] to int")
    except Exception as e:
        print(f"Error converting df_post['{col}']: {e}")

# Verify conversion
print(f"\nAfter conversion:")
print(f"df_pre non-numeric columns: {df_pre.select_dtypes(exclude=[np.number]).columns.tolist()}")
print(f"df_post non-numeric columns: {df_post.select_dtypes(exclude=[np.number]).columns.tolist()}")
# Out:
# 2. DATA TYPE ANALYSIS
# ----------------------------------------
# Non-numeric columns in df_pre: ['subjectID', 'base', 'pospic', 'negpic', 'posant', 'negant', 'habituation', 'p80', 'p85', 'p90', 'p95', 'p100', 'p105', 'p114_t1', 'isi30', 'isi60', 'isi120', 'pCRP', 'pNPY', 'uE', 'uNE']
# Data types:
#   subjectID: object
#   base: object
#   pospic: object
#   negpic: object
#   posant: object
#   negant: object
#   habituation: object
#   p80: object
#   p85: object
#   p90: object
#   p95: object
#   p100: object
#   p105: object
#   p114_t1: object
#   isi30: object
#   isi60: object
#   isi120: object
#   pCRP: object
#   pNPY: object
#   uE: object
#   uNE: object
#
# Non-numeric columns in df_post: ['subjectID', 'base', 'pospic', 'negpic', 'posant', 'negant', 'habituation', 'p80', 'p85', 'p90', 'p95', 'p100', 'p105', 'p114_t1', 'isi30', 'isi60', 'isi120']
# Data types:
#   subjectID: object
#   base: object
#   pospic: object
#   negpic: object
#   posant: object
#   negant: object
#   habituation: object
#   p80: object
#   p85: object
#   p90: object
#   p95: object
#   p100: object
#   p105: object
#   p114_t1: object
#   isi30: object
#   isi60: object
#   isi120: object
#
# Common non-numeric columns: ['p114_t1', 'subjectID', 'habituation', 'posant', 'p105', 'isi60', 'negant', 'p95', 'p90', 'pospic', 'base', 'p100', 'isi30', 'p80', 'p85', 'isi120', 'negpic']
# Non-numeric columns only in pre: ['pCRP', 'pNPY', 'uE', 'uNE']
# Non-numeric columns only in post: []
#
# Sample values from non-numeric columns in df_pre:
#   subjectID: ['1000', '1001', '1002']
#   base: ['60.27', '32.98', '101.99']
#   pospic: ['72', '18.05', '82.2']
#
# Sample values from non-numeric columns in df_post:
#   subjectID: ['1100', '1101', '1103']
#   base: ['187.728', '158.844', '160.728']
#   pospic: ['104.95', '152.8', '171.4']
#
# 3. CONVERTING NON-NUMERIC COLUMNS
# ----------------------------------------
# Converted df_pre['subjectID'] to int
# Converted df_pre['base'] to float
# Converted df_pre['pospic'] to int
# Converted df_pre['negpic'] to float
# Converted df_pre['posant'] to int
# Converted df_pre['negant'] to float
# Converted df_pre['habituation'] to float
# Converted df_pre['p80'] to int
# Converted df_pre['p85'] to int
# Converted df_pre['p90'] to float
# Converted df_pre['p95'] to int
# Converted df_pre['p100'] to float
# Converted df_pre['p105'] to float
# Converted df_pre['p114_t1'] to int
# Converted df_pre['isi30'] to int
# Converted df_pre['isi60'] to int
# Converted df_pre['isi120'] to int
# Converted df_pre['pCRP'] to float
# Converted df_pre['pNPY'] to float
# Converted df_pre['uE'] to float
# Converted df_pre['uNE'] to float
# Converted df_post['subjectID'] to int
# Converted df_post['base'] to float
# Converted df_post['pospic'] to float
# Converted df_post['negpic'] to float
# Converted df_post['posant'] to float
# Converted df_post['negant'] to float
# Converted df_post['habituation'] to float
# Converted df_post['p80'] to float
# Converted df_post['p85'] to float
# Converted df_post['p90'] to int
# Converted df_post['p95'] to int
# Converted df_post['p100'] to int
# Converted df_post['p105'] to int
# Converted df_post['p114_t1'] to int
# Converted df_post['isi30'] to float
# Converted df_post['isi60'] to float
# Converted df_post['isi120'] to float
#
# After conversion:
# df_pre non-numeric columns: []
# df_post non-numeric columns: []

# %%
import pickle
import pandas as pd
import numpy as np

with open('./data/pre_deployment_data.pkl', 'rb') as f:
    data_dict_pre = pickle.load(f)


with open('./data/post_deployment_data.pkl', 'rb') as f:
    data_dict_post = pickle.load(f)

# %%
df_pre = data_dict_pre['merged_df']
df_post = data_dict_post['merged_df']

df_both = pd.concat([df_pre, df_post])

# %%
df_both.drop(columns=['systolic_use','diastolic_use','BMI','waist','MAP'], inplace=True)
df_both.reset_index(drop=True, inplace=True)

# %%
df_both
# Out:
#      subjectID  HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1   HRV_RMSSD  \
# 0         1000  983.301038   72.994026   35.248582   65.454654   70.032978
# 1         1001  801.763380   91.751170   46.864456   81.619311   92.466302
# 2         1002  911.102564   71.794740   40.769253   60.349014   42.174534
# 3         1003  791.738889   74.062487   20.750356   70.493100   52.645077
# 4         1004  902.333333   55.126721   20.058270   51.949080   36.250763
# ...        ...         ...         ...         ...         ...         ...
# 4038      5036  707.094527  144.329410   12.791474  144.259588  202.154986
# 4039      5040  979.065292  130.275090   15.848038  121.698105  174.548758
# 4040      5044  779.060274   38.468221   19.535355   33.181658   37.343593
# 4041      5045  759.064000   40.979533   19.558327   34.573780   37.490783
# 4042      5046  945.405316   56.420403   27.850514   51.037791   47.468024
#
#         HRV_SDSD  HRV_CVNN  HRV_CVSD  HRV_MedianNN  ...   p80   p85   p90  \
# 0      70.154243  0.074234  0.071222         980.0  ...    12    10  11.5
# 1      92.597167  0.114437  0.115329         792.0  ...  14.5  12.5  13.5
# 2      42.240198  0.078800  0.046290         912.5  ...  21.5  15.5   9.5
# 3      52.717267  0.093544  0.066493         785.0  ...    20  31.5    35
# 4      36.308104  0.061094  0.040174         912.0  ...  11.5    12  11.5
# ...          ...       ...       ...           ...  ...   ...   ...   ...
# 4038  202.407521  0.204116  0.285895         669.5  ...   NaN   NaN   NaN
# 4039  174.850465  0.133061  0.178281         999.0  ...  20.5    11    17
# 4040   37.394989  0.049378  0.047934         773.0  ...  10.5  14.5    10
# 4041   37.540955  0.053987  0.049391         759.0  ...  17.5  21.5  13.5
# 4042   47.546164  0.059679  0.050209         949.0  ...    10    10   8.5
#
#        p95  p100  p105  p114_t1   isi30  isi60  isi120
# 0       11  37.5  30.5      211      58     54      50
# 1     18.5  18.5  73.5      189  -102.5     80    77.5
# 2     16.5    60   109    153.5   65.84  85.09   84.47
# 3       35   110  61.5      226    1.96  30.39   37.25
# 4     18.5  49.5    57      313    43.6  70.94   87.68
# ...    ...   ...   ...      ...     ...    ...     ...
# 4038   NaN   NaN   NaN      NaN     NaN    NaN     NaN
# 4039  75.5  93.5    73      413    5.08  28.91   75.39
# 4040  13.5    41    70      173   15.33     -2   25.33
# 4041   8.5    50  42.5      286   52.43  61.08   62.16
# 4042   8.5    12  27.5      131  -18.18      0    9.09
#
# [4043 rows x 219 columns]

# %%
data_dict_post['merged_df'] = df_both

with open('./data/both_deployment_data.pkl', 'wb') as f:
    pickle.dump(data_dict_post, f)
